# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("iris.csv")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df['species'].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
x = df.drop("species",axis=1)
y = df['species']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model_1 = KNeighborsClassifier(metric='minkowski')
model_1.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
from sklearn.metrics import accuracy_score,f1_score,classification_report

# %%
model_1.score(X_test,y_test)
# Out:
# 1.0

# %%
y_predict = model_1.predict(X_test)
accuracy_score(y_predict,y_test)
# Out:
# 1.0

# %%
from sklearn.svm import SVC

# %%
model_SC = SVC(gamma='auto')
model_SC.fit(X_train,y_train)
# Out:
# SVC(gamma='auto')

# %%
model_SC.score(X_test,y_test)
# Out:
# 1.0

# %%
y_predict_Sv = model_1.predict(X_test)
accuracy_score(y_predict_Sv,y_test)
# Out:
# 1.0

# %%
from sklearn.model_selection import GridSearchCV

# %%
classfier = GridSearchCV((model_SC),{
    "C":[1,3,5,8,10,30,40],
    "kernel":['linear','rbf']
},cv=7,return_train_score=False)

# %%
classfier.fit(x,y)
# Out:
# GridSearchCV(cv=7, estimator=SVC(gamma='auto'),
#              param_grid={'C': [1, 3, 5, 8, 10, 30, 40],
#                          'kernel': ['linear', 'rbf']})

# %%
classfier.cv_results_
# Out:
# {'mean_fit_time': array([0.00294648, 0.00341354, 0.00424388, 0.00216007, 0.00143542,
#         0.00187819, 0.00219229, 0.00165248, 0.00145711, 0.00160166,
#         0.00161518, 0.00161059, 0.0013786 , 0.00162074]),
#  'std_fit_time': array([5.31869504e-04, 7.87433707e-04, 2.73626679e-03, 8.18131152e-04,
#         9.74851606e-05, 3.09825411e-04, 9.69192588e-04, 2.77827349e-04,
#         1.74318613e-04, 3.00235370e-04, 2.53913623e-04, 2.55125918e-04,
#         5.29577163e-05, 2.16474746e-04]),
#  'mean_score_time': array([0.00257799, 0.00643277, 0.00248957, 0.00131471, 0.00124274,
#         0.00152683, 0.00138324, 0.00129271, 0.00110899, 0.00136048,
#         0.00124243, 0.00129666, 0.00110446, 0.00125163]),
#  'std_score_time': array([0.00119065, 0.00905232, 0.00100873, 0.00038791, 0.00032468,
#         0.00031681, 0.000553  , 0.00026345, 0.00012783, 0.00036303,
#         0.00030274, 0.00032545, 0.00014314, 0.00027813]),
# ...

# %%
result = pd.DataFrame(classfier.cv_results_)

# %%
result
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.002946      0.000532         0.002578        0.001191        1
# 1        0.003414      0.000787         0.006433        0.009052        1
# 2        0.004244      0.002736         0.002490        0.001009        3
# 3        0.002160      0.000818         0.001315        0.000388        3
# 4        0.001435      0.000097         0.001243        0.000325        5
# 5        0.001878      0.000310         0.001527        0.000317        5
# 6        0.002192      0.000969         0.001383        0.000553        8
# 7        0.001652      0.000278         0.001293        0.000263        8
# 8        0.001457      0.000174         0.001109        0.000128       10
# 9        0.001602      0.000300         0.001360        0.000363       10
# 10       0.001615      0.000254         0.001242        0.000303       30
# 11       0.001611      0.000255         0.001297        0.000325       30
# ...

# %%
result[['param_C','param_kernel','mean_test_score']]
# Out:
#     param_C param_kernel  mean_test_score
# 0         1       linear         0.973408
# 1         1          rbf         0.959802
# 2         3       linear         0.973408
# 3         3          rbf         0.966605
# 4         5       linear         0.973098
# 5         5          rbf         0.973408
# 6         8       linear         0.979901
# 7         8          rbf         0.980210
# 8        10       linear         0.979901
# 9        10          rbf         0.980210
# 10       30       linear         0.966605
# 11       30          rbf         0.946506
# 12       40       linear         0.966605
# 13       40          rbf         0.952999

# %%
classfier_2 = GridSearchCV((model_1),{
    "n_neighbors":[1,3,5,7,15,33,45],
    "weights":['uniform','distance']
},cv=7,return_train_score=False)

# %%
classfier_2.fit(x,y)
# Out:
# GridSearchCV(cv=7, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': [1, 3, 5, 7, 15, 33, 45],
#                          'weights': ['uniform', 'distance']})

# %%
classfier_2.cv_results_
# Out:
# {'mean_fit_time': array([0.00278933, 0.00142894, 0.00187189, 0.00170333, 0.00144689,
#         0.00154499, 0.00146627, 0.00146433, 0.00198099, 0.00162871,
#         0.00154161, 0.00158886, 0.00128736, 0.00146198]),
#  'std_fit_time': array([6.00514095e-04, 1.47805392e-04, 7.02010179e-04, 3.23975214e-04,
#         2.04297545e-04, 2.65505012e-04, 2.38976337e-04, 2.81216838e-04,
#         1.12505852e-03, 4.15660147e-04, 4.21542137e-04, 5.01292761e-04,
#         7.10015009e-05, 2.55435503e-04]),
#  'mean_score_time': array([0.00721145, 0.00170646, 0.00376473, 0.00188225, 0.00310258,
#         0.00164764, 0.00267931, 0.0019552 , 0.00321715, 0.00178041,
#         0.00256198, 0.0016861 , 0.0027303 , 0.00161321]),
#  'std_score_time': array([0.00230481, 0.00045521, 0.00162481, 0.00027655, 0.00094312,
#         0.00034383, 0.00035617, 0.00064417, 0.00106933, 0.00053386,
#         0.00023896, 0.00023858, 0.00045677, 0.00024521]),
# ...

# %%
result_2 = pd.DataFrame(classfier_2.cv_results_)

# %%
result_2[['param_n_neighbors','param_weights','mean_test_score']]
# Out:
#     param_n_neighbors param_weights  mean_test_score
# 0                   1       uniform         0.960111
# 1                   1      distance         0.960111
# 2                   3       uniform         0.966914
# 3                   3      distance         0.966914
# 4                   5       uniform         0.966605
# 5                   5      distance         0.966605
# 6                   7       uniform         0.966605
# 7                   7      distance         0.973408
# 8                  15       uniform         0.959802
# 9                  15      distance         0.966605
# 10                 33       uniform         0.946506
# 11                 33      distance         0.960111
# 12                 45       uniform         0.947124
# 13                 45      distance         0.960111
